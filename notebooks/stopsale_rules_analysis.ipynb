# %%
from pathlib import Path

import numpy as np
import pandas as pd

from database import Database

# %%
base_dir = Path(".").resolve()
data_dir = base_dir / "data"

db = Database()

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", "{:.2f}".format)

# %%
from sqlalchemy import Integer, case, cast, func, select
from sqlalchemy.dialects.postgresql import JSONB
from sqlalchemy.sql import and_, or_

# Define the table reference
# Assuming ss is an alias for the reports_specificstopsalesrules table
ss = db.reports_specificstopsalesrules

# Build the query
query = select(
    ss.c.rule_id,
    ss.c.last_date.label("last_updated"),
    ss.c.levels_rules["cli"]["t"].astext.label("credential_level"),
    ss.c.levels_rules["cli"]["l"].astext.label("credential_id"),
    ss.c.levels_rules["prv"]["t"].astext.label("provider_level"),
    ss.c.levels_rules["prv"]["l"].astext.label("provider_id"),
    ss.c.levels_rules["hot"]["t"].astext.label("hotel_level"),
    ss.c.levels_rules["hot"]["l"].astext.label("hotel_id"),
    ss.c.levels_rules["dest"]["t"].astext.label("destination_level"),
    ss.c.levels_rules["dest"]["l"].astext.label("destination_id"),
    case(
        [
            (
                or_(
                    cast(func.coalesce(ss.c.levels_rules["cp"], 0), Integer)
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["ps"]["t"], 0), Integer
                    )
                    > 0,
                    cast(func.coalesce(ss.c.levels_rules["rat"], 0), Integer)
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["mrk"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["mel"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["cid"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["bod"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["rrg"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(func.coalesce(ss.c.levels_rules["rel"], 0), Integer)
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["dow"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(func.coalesce(ss.c.levels_rules["age"], 0), Integer)
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["room"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["non"]["t"], 0),
                        Integer,
                    )
                    > 0,
                    cast(
                        func.coalesce(ss.c.levels_rules["hou"]["t"], 0),
                        Integer,
                    )
                    > 0,
                ),
                True,
            )
        ],
        else_=False,
    ).label("has_attributes"),
).where(
    ss.c.tag.in_([-1, 1, 3]), ss.c.organization == "lgt", ss.c.active == True
)

# Print the query
print(query)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[4], line 21
#       7 ss = db.reports_specificstopsalesrules
#       9 # Build the query
#      10 query = select(
#      11     ss.c.rule_id,
#      12     ss.c.last_date.label("last_updated"),
#      13     ss.c.levels_rules["cli"]["t"].astext.label("credential_level"),
#      14     ss.c.levels_rules["cli"]["l"].astext.label("credential_id"),
#      15     ss.c.levels_rules["prv"]["t"].astext.label("provider_level"),
#      16     ss.c.levels_rules["prv"]["l"].astext.label("provider_id"),
#      17     ss.c.levels_rules["hot"]["t"].astext.label("hotel_level"),
#      18     ss.c.levels_rules["hot"]["l"].astext.label("hotel_id"),
#      19     ss.c.levels_rules["dest"]["t"].astext.label("destination_level"),
#      20     ss.c.levels_rules["dest"]["l"].astext.label("destination_id"),
# ---> 21     case(
#      22         [
#      23             (
#      24                 or_(
#      25                     cast(func.coalesce(ss.c.levels_rules["cp"], 0), Integer)
#      26                     > 0,
#      27                     cast(
#      28                         func.coalesce(ss.c.levels_rules["ps"]["t"], 0), Integer
#      29                     )
#      30                     > 0,
#      31                     cast(func.coalesce(ss.c.levels_rules["rat"], 0), Integer)
#      32                     > 0,
#      33                     cast(
#      34                         func.coalesce(ss.c.levels_rules["mrk"]["t"], 0),
#      35                         Integer,
#      36                     )
#      37                     > 0,
#      38                     cast(
#      39                         func.coalesce(ss.c.levels_rules["mel"]["t"], 0),
#      40                         Integer,
#      41                     )
#      42                     > 0,
#      43                     cast(
#      44                         func.coalesce(ss.c.levels_rules["cid"]["t"], 0),
#      45                         Integer,
#      46                     )
#      47                     > 0,
#      48                     cast(
#      49                         func.coalesce(ss.c.levels_rules["bod"]["t"], 0),
#      50                         Integer,
#      51                     )
#      52                     > 0,
#      53                     cast(
#      54                         func.coalesce(ss.c.levels_rules["rrg"]["t"], 0),
#      55                         Integer,
#      56                     )
#      57                     > 0,
#      58                     cast(func.coalesce(ss.c.levels_rules["rel"], 0), Integer)
#      59                     > 0,
#      60                     cast(
#      61                         func.coalesce(ss.c.levels_rules["dow"]["t"], 0),
#      62                         Integer,
#      63                     )
#      64                     > 0,
#      65                     cast(func.coalesce(ss.c.levels_rules["age"], 0), Integer)
#      66                     > 0,
#      67                     cast(
#      68                         func.coalesce(ss.c.levels_rules["room"]["t"], 0),
#      69                         Integer,
#      70                     )
#      71                     > 0,
#      72                     cast(
#      73                         func.coalesce(ss.c.levels_rules["non"]["t"], 0),
#      74                         Integer,
#      75                     )
#      76                     > 0,
#      77                     cast(
#      78                         func.coalesce(ss.c.levels_rules["hou"]["t"], 0),
#      79                         Integer,
#      80                     )
#      81                     > 0,
#      82                 ),
#      83                 True,
#      84             )
#      85         ],
#      86         else_=False,
#      87     ).label("has_attributes"),
#      88 ).where(
#      89     ss.c.tag.in_([-1, 1, 3]), ss.c.organization == "lgt", ss.c.active == True
#      90 )
#      92 # Print the query
#      93 print(query)
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/sql/_elements_constructors.py:850, in case(value, else_, *whens)
#     723 def case(
#     724     *whens: Union[
#     725         typing_Tuple[_ColumnExpressionArgument[bool], Any], Mapping[Any, Any]
#    (...)
#     728     else_: Optional[Any] = None,
#     729 ) -> Case[Any]:
#     730     r"""Produce a ``CASE`` expression.
#     731
#     732     The ``CASE`` construct in SQL is a conditional object that
#    (...)
#     848
#     849     """
# --> 850     return Case(*whens, value=value, else_=else_)
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:3390, in Case.__init__(self, value, else_, *whens)
#    3381 def __init__(
#    3382     self,
#    3383     *whens: Union[
#    (...)
#    3388     else_: Optional[Any] = None,
#    3389 ):
# -> 3390     new_whens: Iterable[Any] = coercions._expression_collection_was_a_list(
#    3391         "whens", "case", whens
#    3392     )
#    3393     try:
#    3394         new_whens = util.dictlike_iteritems(new_whens)
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/sql/coercions.py:152, in _expression_collection_was_a_list(attrname, fnname, args)
#     150 if args and isinstance(args[0], (list, set, dict)) and len(args) == 1:
#     151     if isinstance(args[0], list):
# --> 152         raise exc.ArgumentError(
#     153             f'The "{attrname}" argument to {fnname}(), when '
#     154             "referring to a sequence "
#     155             "of items, is now passed as a series of positional "
#     156             "elements, rather than as a list. "
#     157         )
#     158     return cast("Sequence[_T]", args[0])
#     160 return cast("Sequence[_T]", args)
#
# ArgumentError: The "whens" argument to case(), when referring to a sequence of items, is now passed as a series of positional elements, rather than as a list.
